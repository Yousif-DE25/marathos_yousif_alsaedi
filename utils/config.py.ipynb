# %%
CATALOG = "marathos"

SCHEMAS = {
    "bronze": f"{CATALOG}.bronze",
    "silver": f"{CATALOG}.silver",
    "gold":   f"{CATALOG}.gold",
}

# Sökväg till rå CSV-fil i Unity Catalog volymen
RAW_DATA_PATH = f"/Volumes/{CATALOG}/default/raw/TWO_CENTURIES_OF_UM_RACES.csv"

# Tabellnamn
BRONZE_TABLE = f"{SCHEMAS['bronze']}.ultra_marathon_raw"
SILVER_TABLE = f"{SCHEMAS['silver']}.ultra_marathon_obt"
